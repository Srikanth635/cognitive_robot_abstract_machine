# %% [markdown]
# # Generative Backend — Unified Action Pipeline
#
# Demonstrates the universal `ActionPipeline` handling **both PickUp and Place**
# from a single entry point without knowing the action type in advance.
#
# **Key design points:**
# - One pipeline class, any action type
# - One slot-filling LLM call classifies the action **and** extracts parameters
# - The result is a clean per-action schema: `PickUpSlotSchema` or `PlaceSlotSchema`
# - An `ActionDispatcher` registry routes each schema to the correct handler
# - A **generic resolver node** (`workflows/nodes/resolver.py`) handles Phase 2 for all
#   action types — new actions only need a prompt and a schema class
#
# **Package layout (relevant):**
# ```
# generative_backend/
# ├── action_pipeline.py          ← entry point
# ├── action_dispatcher.py        ← handler registry
# ├── entity_grounder.py          ← NL description → world Body
# └── workflows/
#     ├── nodes/
#     │   ├── slot_filler.py      ← Phase 1: classify + extract (all actions)
#     │   └── resolver.py         ← Phase 2: discrete resolution (generic, all actions)
#     ├── schemas/
#     │   ├── common.py           ← EntityDescriptionSchema (shared across all actions)
#     │   ├── pick_up.py
#     │   └── place.py
#     └── prompts/
#         ├── pick_up.py
#         └── place.py
# ```
#
# **Stages shown:**
# 1. **Slot filling** — one LLM call returns a typed per-action schema
# 2. **PickUp full run** — end-to-end `PickUpAction` via `pipeline.run()`
# 3. **Place full run** — end-to-end `PlaceAction` via the same `pipeline.run()`
# 4. **Step-by-step breakdown** — `classify_and_extract()` → `dispatch()` for both
# 5. **Generic resolver** — calling `run_resolver()` directly with any prompt + schema
#
# **Prerequisites:** `cd cognitive_robot_abstract_machine && uv sync --active`
# **API key:** set `OPENAI_API_KEY` in `generative_backend/.env`

# %% [markdown]
# ## 1 · Environment & Imports

# %%
import logging
import pathlib
from dotenv import load_dotenv

# Load API keys before any LLM import
_env = pathlib.Path().resolve().parent / ".env"
load_dotenv(_env, override=True)

logging.basicConfig(level=logging.WARNING, format="%(levelname)s %(name)s: %(message)s")

# ── SDT / pycram stack ────────────────────────────────────────────────────────
from semantic_digital_twin.robots.pr2 import PR2
from pycram.testing import setup_world

# ── Generative backend — pipeline entry point ─────────────────────────────────
from generative_backend.action_pipeline import ActionPipeline

# ── Schemas (common + action-specific) ───────────────────────────────────────
from generative_backend.workflows.schemas.common import EntityDescriptionSchema
from generative_backend.workflows.schemas.pick_up import PickUpSlotSchema
from generative_backend.workflows.schemas.place import PlaceSlotSchema

# ── LangGraph nodes (Phase 1 + generic Phase 2) ───────────────────────────────
from generative_backend.workflows.nodes.slot_filler import run_slot_filler
from generative_backend.workflows.nodes.resolver import (
    run_resolver,
    run_pickup_resolver,
    run_place_resolver,
)

print("All imports OK")
# Out:
# /home/malineni/envs/cram-env/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Found these qp solvers: ['qpSWIFT', 'qpalm']
# WARNING polytope.solvers: `polytope` failed to import `cvxopt.glpk`.
# WARNING polytope.solvers: will use `scipy.optimize.linprog`
# All imports OK

# %%
import logging

# Set DEBUG on the generative_backend namespace only — keeps SDT/pycram noise at WARNING.
# Toggle to logging.WARNING to suppress again.
logging.getLogger("generative_backend").setLevel(logging.DEBUG)

# %% [markdown]
# ## 2 · Load World
#
# `setup_world()` loads the apartment URDF, a PR2 robot, a milk carton (`milk.stl`),
# and a breakfast cereal box. The milk sits on the kitchen counter.
#
# We will use:
# - **Pick-up instruction** — grab the milk from the counter
# - **Place instruction** — put the milk on the table

# %%
world = setup_world()

try:
    robot = PR2.from_world(world)
except Exception as exc:
    print(f"Note: PR2 full setup skipped ({type(exc).__name__}) — recovering annotation")
    robot = next((a for a in world.semantic_annotations if isinstance(a, PR2)), None)
    if robot is None:
        raise RuntimeError("Could not obtain PR2 annotation") from exc
    with world.modify_world():
        robot._setup_velocity_limits()
        robot._setup_hardware_interfaces()
        robot._setup_joint_states()

# Confirm key bodies are present
milk_body = world.get_body_by_name("milk.stl")
milk_pos  = milk_body.global_pose.to_position()
print(f"World loaded")
print(f"  milk  → x={float(milk_pos.x):.2f}, y={float(milk_pos.y):.2f}, z={float(milk_pos.z):.2f}")

# Show all bodies so we can pick an appropriate place target
all_body_names = [
    str(getattr(getattr(b, "name", None), "name", b))
    for b in world.bodies
]
print(f"  bodies present ({len(all_body_names)}): {', '.join(all_body_names[:20])}")
# Out:
# Unknown attribute "type" in /robot[@name='pr2']/link[@name='base_laser_link']
# Unknown attribute "type" in /robot[@name='pr2']/link[@name='wide_stereo_optical_frame']
# Unknown attribute "type" in /robot[@name='pr2']/link[@name='narrow_stereo_optical_frame']
# Unknown attribute "type" in /robot[@name='pr2']/link[@name='laser_tilt_link']
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_footprint
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_footprint
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_bellow_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_laser_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fl_caster_l_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fl_caster_r_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fr_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fr_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fr_caster_l_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fr_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/fr_caster_r_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/bl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/bl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/bl_caster_l_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/bl_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/bl_caster_r_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/br_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/br_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/br_caster_l_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/br_caster_rotation_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/br_caster_r_wheel_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_torso_lift_side_plate_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_torso_lift_side_plate_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_motor_screw_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/imu_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_tilt_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_tilt_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/sensor_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/sensor_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/high_def_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/high_def_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/high_def_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/sensor_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/double_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/double_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/double_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_child_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_led_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_accelerometer_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_tool_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_screw_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_tip_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_adapter_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_adapter_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_led_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_accelerometer_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_tool_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_screw_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_tip_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_optical_frame
# Unknown tag "material" in /robot[@name='apartment']/link[@name='coffe_machine']/collision[1]
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/walls
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/windows
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wall_coloksu_wall1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wall_coloksu_wall2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wall_coloksu_wall3
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wall_coloksu_wall4
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_left_handle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_right
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_right
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/wardrobe_door_right_handle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/armchair
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/sofa
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/coffee_table
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/coffee_table
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/coffee_table_drawer
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/furnitures_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/bedside_table
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/kitchen_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/kitchen_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/kitchen_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_door_top_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_door_top_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab1_top_door
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/oven
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab1_drawer_mid
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab1_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_coloksu_level4
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet1_coloksu_level5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_door_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_door_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_door_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_door_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab2_door
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_drawer_small
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet2_drawer_big
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_top_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_top_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_top_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_top_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab3_door_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_bottom_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_bottom_out_fancy
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_bottom_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet3_door_bottom_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab3_door_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4_door_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4_door_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4_door_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet4_door_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab4_door_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab5_t
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab5_m
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab5_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab6_t
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab6_m
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet6_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab6_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet7
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet7
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet7_door_bottom_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet7_door_bottom_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab7
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet7
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/dishwasher_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/dishwasher_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab7_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet8_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab8
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab9_t
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab9_m
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet9_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab9_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab10_t
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab10_m
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet10_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab10_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_top
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab11_t
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_middle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab11_m
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet11_drawer_bottom
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/handle_cab11_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_countertop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_countertop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cooktop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cooktop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/hotplate1
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cooktop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/hotplate2
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cooktop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/hotplate3
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cooktop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/hotplate4
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_countertop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/sink
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/sink
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/tap_body
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/tap_body
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/tap_handle_open
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/tap_handle_open
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/tap_handle
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/useless_underbar_a
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/useless_underbar_b
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/cabinet5
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/countertop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/countertop
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/coffe_machine
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_waterfall_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_waterfall_right
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_B
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/island_back
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A_left
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A_rt
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/side_A_rb
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/table_area_main
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name milk.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name breakfast_cereal.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name milk.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name milk.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name breakfast_cereal.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name breakfast_cereal.stl
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_footprint
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_bellow_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_link
# ...
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/wide_stereo_r_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/double_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_l_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/narrow_stereo_r_stereo_camera_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/projector_wg6802418_child_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_plate_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_ir_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_kinect_rgb_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/head_mount_prosilica_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_mount_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/laser_tilt_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_led_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_accelerometer_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_tool_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_motor_screw_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_gripper_l_finger_tip_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/torso_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_pan_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_shoulder_lift_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_upper_arm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_elbow_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_flex_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_wrist_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_adapter_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_adapter_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_force_torque_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_led_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_accelerometer_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_tool_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_slider_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_motor_screw_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_palm_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_r_finger_tip_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_gripper_l_finger_tip_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/l_forearm_cam_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_roll_link
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/r_forearm_cam_optical_frame
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_footprint
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name apartment/apartment_root
# INFO semantic_digital_twin.world: Trying to add kinematic_structure_entity with name pr2/base_footprint
# Note: PR2 full setup skipped (WorldEntityNotFoundError) — recovering annotation
# World loaded
#   milk  → x=2.37, y=2.00, z=1.05
#   bodies present (212): apartment_root, furnitures_root, walls, windows, wall_coloksu_wall1, wall_coloksu_wall2, wall_coloksu_wall3, wall_coloksu_wall4, wardrobe, wardrobe_door_left, wardrobe_door_left_handle, wardrobe_door_right, wardrobe_door_right_handle, armchair, sofa, coffee_table, coffee_table_drawer, bedside_table, kitchen_root, side_A

# %% [markdown]
# ## 3 · Initialise Unified Pipeline
#
# `ActionPipeline.from_world()` auto-detects the robot manipulator and builds
# one pipeline object that handles **any** registered action type.

# %%
pipeline = ActionPipeline.from_world(world)

print("ActionPipeline ready")
print(f"  manipulator : {type(pipeline.world_context.manipulator).__name__}")

# Show which action types are registered in the dispatcher
from generative_backend.action_dispatcher import ActionDispatcher
print(f"  registered action types: {list(ActionDispatcher._registry.keys())}")
# Out:
# ActionPipeline ready
#   manipulator : ParallelGripper
#   registered action types: ['PickUpAction', 'PlaceAction']

# %% [markdown]
# ## 4 · Slot Filling — Per-Action Schema
#
# A **single LLM call** (`nodes/slot_filler.py`) classifies the instruction into
# an action type *and* extracts all relevant parameters.  The result is a clean,
# typed schema specific to that action:
#
# - `PickUpSlotSchema` — fields: `object_description`, `arm`, `grasp_params`
# - `PlaceSlotSchema`  — fields: `object_description`, `arm`, `target_description`
#
# Both `object_description` and `target_description` are `EntityDescriptionSchema`
# instances (defined once in `schemas/common.py`) — a target surface is described
# with the same four fields (`name`, `semantic_type`, `spatial_context`, `attributes`)
# as any pickable object.  No mixed optional fields from other action types leak through.

# %%
PICKUP_INSTRUCTION = "Pick up the milk from the counter"

pickup_schema: PickUpSlotSchema = pipeline.classify_and_extract(PICKUP_INSTRUCTION)

print(f"Instruction : {PICKUP_INSTRUCTION!r}")
print(f"Schema type : {type(pickup_schema).__name__}  ← typed by LLM classification")
print()
print("PickUpSlotSchema:")
print(f"  action_type          : {pickup_schema.action_type}")
print(f"  object.name          : {pickup_schema.object_description.name}")
print(f"  object.semantic_type : {pickup_schema.object_description.semantic_type}")
print(f"  object.spatial       : {pickup_schema.object_description.spatial_context}")
print(f"  arm                  : {pickup_schema.arm}   ← null = unspecified")
print(f"  grasp_params         : {pickup_schema.grasp_params}   ← null = unspecified")
# Out:
# DEBUG generative_backend.action_pipeline: World context for slot filling:
# ## World State Summary
#
# Bodies present: apartment_root, furnitures_root, walls, windows, wall_coloksu_wall1, wall_coloksu_wall2, wall_coloksu_wall3, wall_coloksu_wall4, wardrobe, wardrobe_door_left, wardrobe_door_left_handle, wardrobe_door_right, wardrobe_door_right_handle, armchair, sofa, coffee_table, coffee_table_drawer, bedside_table, kitchen_root, side_A, side_B, cabinet1, cabinet1_door_top_left, handle_cab1_top_door, oven, cabinet1_drawer_middle, handle_cab1_drawer_mid, cabinet1_drawer_bottom, handle_cab1_drawer_bottom, cabinet1_coloksu_level4
#   … and 182 more.
# DEBUG generative_backend.workflows.nodes.slot_filler: slot_filler_node – action_type=PickUpAction, object=milk
# INFO generative_backend.action_pipeline: classify_and_extract – action_type=PickUpAction, object='milk', arm=None
# Instruction : 'Pick up the milk from the counter'
# Schema type : PickUpSlotSchema  ← typed by LLM classification
#
# PickUpSlotSchema:
#   action_type          : PickUpAction
#   object.name          : milk
#   object.semantic_type : FoodItem
#   object.spatial       : from the counter
#   arm                  : None   ← null = unspecified
#   grasp_params         : None   ← null = unspecified

# %%
PLACE_INSTRUCTION = "Place the milk on the table"

place_schema: PlaceSlotSchema = pipeline.classify_and_extract(PLACE_INSTRUCTION)

print(f"Instruction : {PLACE_INSTRUCTION!r}")
print(f"Schema type : {type(place_schema).__name__}  ← typed by LLM classification")
print()
print("PlaceSlotSchema:")
print(f"  action_type               : {place_schema.action_type}")
print(f"  object.name               : {place_schema.object_description.name}")
print(f"  object.semantic_type      : {place_schema.object_description.semantic_type}")
print(f"  arm                       : {place_schema.arm}   ← null = unspecified")
print()
# target_description is EntityDescriptionSchema — same four fields as object_description
print(f"  target.name               : {place_schema.target_description.name}")
print(f"  target.semantic_type      : {place_schema.target_description.semantic_type}")
print(f"  target.spatial_context    : {place_schema.target_description.spatial_context}")
print(f"  target.attributes         : {place_schema.target_description.attributes}")
print()
print(f"  type(object_description)  : {type(place_schema.object_description).__name__}")
print(f"  type(target_description)  : {type(place_schema.target_description).__name__}  ← same EntityDescriptionSchema")
# Out:
# DEBUG generative_backend.action_pipeline: World context for slot filling:
# ## World State Summary
#
# Bodies present: apartment_root, furnitures_root, walls, windows, wall_coloksu_wall1, wall_coloksu_wall2, wall_coloksu_wall3, wall_coloksu_wall4, wardrobe, wardrobe_door_left, wardrobe_door_left_handle, wardrobe_door_right, wardrobe_door_right_handle, armchair, sofa, coffee_table, coffee_table_drawer, bedside_table, kitchen_root, side_A, side_B, cabinet1, cabinet1_door_top_left, handle_cab1_top_door, oven, cabinet1_drawer_middle, handle_cab1_drawer_mid, cabinet1_drawer_bottom, handle_cab1_drawer_bottom, cabinet1_coloksu_level4
#   … and 182 more.
# DEBUG generative_backend.workflows.nodes.slot_filler: slot_filler_node – action_type=PlaceAction, object=milk
# INFO generative_backend.action_pipeline: classify_and_extract – action_type=PlaceAction, object='milk', arm=None
# Instruction : 'Place the milk on the table'
# Schema type : PlaceSlotSchema  ← typed by LLM classification
#
# PlaceSlotSchema:
#   action_type               : PlaceAction
#   object.name               : milk
#   object.semantic_type      : FoodItem
#   arm                       : None   ← null = unspecified
#
#   target.name               : table
#   target.semantic_type      : Artifact
#   target.spatial_context    : None
#   target.attributes         : None
#
#   type(object_description)  : EntityDescriptionSchema
#   type(target_description)  : EntityDescriptionSchema  ← same EntityDescriptionSchema

# %% [markdown]
# ## 5 · PickUp — Full Pipeline Run
#
# `pipeline.run()` handles the entire chain:
# 1. **Phase 1** — `nodes/slot_filler.py`: one LLM call → `PickUpSlotSchema`
# 2. **Grounding** — `entity_grounder.py`: resolves `"milk"` to the `milk.stl` world body
# 3. **Phase 2** — `nodes/resolver.py` via `run_pickup_resolver()`: LLM reasons over world
#    context to fill `arm`, `approach_direction`, `vertical_alignment`, `rotate_gripper`
# 4. Returns a fully specified `PickUpAction`

# %%
pickup_action = pipeline.run(PICKUP_INSTRUCTION)

gd = pickup_action.grasp_description
obj_name = str(getattr(getattr(pickup_action.object_designator, "name", None), "name",
                        pickup_action.object_designator))

print(f"PickUpAction resolved from: {PICKUP_INSTRUCTION!r}")
print()
print(f"  object_designator  : {obj_name}")
print(f"  arm                : {pickup_action.arm}")
print(f"  approach_direction : {gd.approach_direction}")
print(f"  vertical_alignment : {gd.vertical_alignment}")
print(f"  rotate_gripper     : {gd.rotate_gripper}")
print(f"  manipulator        : {type(gd.manipulator).__name__}")
# Out:
# INFO generative_backend.action_pipeline: ActionPipeline.run: 'Pick up the milk from the counter'
# DEBUG generative_backend.action_pipeline: World context for slot filling:
# ## World State Summary
#
# Bodies present: apartment_root, furnitures_root, walls, windows, wall_coloksu_wall1, wall_coloksu_wall2, wall_coloksu_wall3, wall_coloksu_wall4, wardrobe, wardrobe_door_left, wardrobe_door_left_handle, wardrobe_door_right, wardrobe_door_right_handle, armchair, sofa, coffee_table, coffee_table_drawer, bedside_table, kitchen_root, side_A, side_B, cabinet1, cabinet1_door_top_left, handle_cab1_top_door, oven, cabinet1_drawer_middle, handle_cab1_drawer_mid, cabinet1_drawer_bottom, handle_cab1_drawer_bottom, cabinet1_coloksu_level4
#   … and 182 more.
# DEBUG generative_backend.workflows.nodes.slot_filler: slot_filler_node – action_type=PickUpAction, object=milk
# INFO generative_backend.action_pipeline: classify_and_extract – action_type=PickUpAction, object='milk', arm=None
# INFO generative_backend.action_dispatcher: Dispatching to PickUpAction handler.
# DEBUG generative_backend.entity_grounder: Cannot resolve 'FoodItem' to a SemanticAnnotation subclass.
# DEBUG generative_backend.entity_grounder: Annotation grounding for type 'FoodItem' returned no results, falling back to name search.
# INFO generative_backend.action_dispatcher: PickUp grounding – 1 body/bodies (tier=name).
# DEBUG generative_backend.action_dispatcher: PickUp world context:
# Robot position: x=1.500, y=2.500, z=0.051
# Object 'milk.stl': x=2.370, y=2.000, z=1.050
#   → 0.87m in front of and 0.50m to the right of the robot, 1.00m above robot origin.
#   → Bounding box (w×d×h): 0.064 × 0.065 × 0.194 m
# DEBUG generative_backend.action_dispatcher: PickUp known parameters: None – all discrete parameters are unspecified.
# DEBUG generative_backend.action_dispatcher: PickUp missing parameters: arm  (choose LEFT or RIGHT based on object position)
# approach_direction  (FRONT / BACK / LEFT / RIGHT)
# vertical_alignment  (TOP / BOTTOM / NoAlignment)
# rotate_gripper      (true / false)
# DEBUG generative_backend.workflows.nodes.resolver: resolver_node (PickUpDiscreteResolutionSchema) – {'arm': 'RIGHT', 'approach_direction': 'FRONT', 'vertical_alignment': 'TOP', 'rotate_gripper': False, 'reasoning': "The object is located to the right of the robot, making the RIGHT arm preferable. Approaching from the FRONT provides the best clearance while aligning the gripper from above is suitable for the object's flat shape."}
# DEBUG generative_backend.action_dispatcher: LLM reasoning: The object is located to the right of the robot, making the RIGHT arm preferable. Approaching from the FRONT provides the best clearance while aligning the gripper from above is suitable for the object's flat shape.
# INFO generative_backend.action_pipeline: ActionPipeline.dispatch complete – PickUpAction resolved.
# PickUpAction resolved from: 'Pick up the milk from the counter'
#
#   object_designator  : milk.stl
#   arm                : RIGHT
#   approach_direction : ApproachDirection.FRONT
#   vertical_alignment : VerticalAlignment.TOP
#   rotate_gripper     : False
#   manipulator        : ParallelGripper

# %% [markdown]
# ## 6 · Place — Full Pipeline Run
#
# The **same** `pipeline.run()` call now handles a place instruction:
# 1. **Phase 1** — `nodes/slot_filler.py`: one LLM call → `PlaceSlotSchema`
# 2. **Grounding** — `entity_grounder.py`: grounds **two** `EntityDescriptionSchema`
#    instances — the object and the target surface (same schema type, different roles)
# 3. **Phase 2** — `nodes/resolver.py` via `run_place_resolver()`: LLM resolves arm
#    based on target surface position relative to robot
# 4. Returns a fully specified `PlaceAction`

# %%
place_action = pipeline.run(PLACE_INSTRUCTION)

obj_name = str(getattr(getattr(place_action.object_designator, "name", None), "name",
                        place_action.object_designator))
tgt_name = str(getattr(getattr(place_action.target_location, "name", None), "name",
                        place_action.target_location))

print(f"PlaceAction resolved from: {PLACE_INSTRUCTION!r}")
print()
print(f"  object_designator  : {obj_name}")
print(f"  arm                : {place_action.arm}")
print(f"  target_location    : {tgt_name}")

# %% [markdown]
# ## 7 · Step-by-Step: Classify → Dispatch
#
# `pipeline.run()` is a convenience wrapper around two explicit steps:
#
# ```python
# schema = pipeline.classify_and_extract(instruction)  # LLM call → PickUpSlotSchema | PlaceSlotSchema
# action = pipeline.dispatch(schema)                   # ground + resolve → concrete action
# ```
#
# Splitting the steps is useful for inspection or overriding schema fields
# before committing to execution (e.g. forcing a specific arm).

# %%
# ── Step 1: classify + extract ─────────────────────────────────────────────────
schema = pipeline.classify_and_extract(PICKUP_INSTRUCTION)
print(f"classify_and_extract({PICKUP_INSTRUCTION!r})")
print(f"  → action_type = {schema.action_type}")
print(f"  → object      = {schema.object_description.name!r}")
print()

# (optional) inspect / override before dispatching
# e.g. schema.arm = "LEFT"  # force left arm

# ── Step 2: dispatch to handler ───────────────────────────────────────────────
action = pipeline.dispatch(schema)
gd = action.grasp_description
print(f"dispatch(schema) → {type(action).__name__}")
print(f"  arm                : {action.arm}")
print(f"  approach_direction : {gd.approach_direction}")
print(f"  vertical_alignment : {gd.vertical_alignment}")
print(f"  rotate_gripper     : {gd.rotate_gripper}")

# %%
# ── Step 1: classify + extract ─────────────────────────────────────────────────
schema = pipeline.classify_and_extract(PLACE_INSTRUCTION)
print(f"classify_and_extract({PLACE_INSTRUCTION!r})")
print(f"  → action_type  = {schema.action_type}")
print(f"  → object       = {schema.object_description.name!r}")
print(f"  → target       = {schema.target_description.name!r}")
print()

# ── Step 2: dispatch to handler ───────────────────────────────────────────────
action = pipeline.dispatch(schema)
obj_name = str(getattr(getattr(action.object_designator, "name", None), "name",
                        action.object_designator))
tgt_name = str(getattr(getattr(action.target_location, "name", None), "name",
                        action.target_location))
print(f"dispatch(schema) → {type(action).__name__}")
print(f"  object_designator  : {obj_name}")
print(f"  arm                : {action.arm}")
print(f"  target_location    : {tgt_name}")

# %% [markdown]
# ## 8 · Both Actions Back-to-Back
#
# To make the contrast clear: the same three lines of code work for any instruction,
# regardless of whether it's a pick-up, a place, or any other registered action type.

# %%
instructions = [
    "Pick up the milk from the counter",
    "Place the milk on the table",
]

for instr in instructions:
    action = pipeline.run(instr)
    print(f"Instruction : {instr!r}")
    print(f"  → {type(action).__name__}")
    print(f"     arm = {action.arm}")
    if hasattr(action, "grasp_description") and action.grasp_description:
        gd = action.grasp_description
        print(f"     approach_direction = {gd.approach_direction}")
        print(f"     vertical_alignment = {gd.vertical_alignment}")
        print(f"     rotate_gripper     = {gd.rotate_gripper}")
    if hasattr(action, "target_location") and action.target_location is not None:
        tgt = str(getattr(getattr(action.target_location, "name", None), "name",
                          action.target_location))
        print(f"     target_location    = {tgt}")
    print()

# %% [markdown]
# ## 9 · Generic Resolver — Calling Phase 2 Directly
#
# `nodes/resolver.py` exposes a single `run_resolver()` function that works for
# **any** action type.  The typed wrappers (`run_pickup_resolver`, `run_place_resolver`)
# are thin convenience calls on top of it.
#
# ```python
# # Under the hood, run_pickup_resolver() is just:
# run_resolver(
#     world_context=...,
#     known_parameters=...,
#     parameters_to_resolve=...,
#     prompt=pick_up_resolver_prompt,      # injected
#     schema_cls=PickUpDiscreteResolutionSchema,  # injected
# )
# ```
#
# Adding a **new action type** (e.g. `PushAction`) requires only:
# 1. A new `PushDiscreteResolutionSchema` in `schemas/`
# 2. A new prompt in `prompts/`
# 3. A three-line typed wrapper in `nodes/resolver.py`
#
# No changes to `resolver.py`'s graph logic, `action_pipeline.py`, or `action_dispatcher.py`.

# %%
from generative_backend.workflows.prompts.pick_up import pick_up_resolver_prompt
from generative_backend.workflows.schemas.pick_up import PickUpDiscreteResolutionSchema

# Demonstrate run_resolver() called directly with an explicit world context string.
# In normal use the handler builds this string from live world poses;
# here we construct a minimal example manually.
_world_ctx = (
    "Robot position: x=0.000, y=0.000, z=0.000\n"
    "Object 'milk': x=1.200, y=-0.350, z=0.850\n"
    "  → 1.20m in front of and 0.35m to the right of the robot, "
    "0.85m above robot origin.\n"
    "  → Semantic types: Milk, FoodItem\n"
    "  → Bounding box (w×d×h): 0.070 × 0.070 × 0.200 m"
)

resolution = run_resolver(
    world_context=_world_ctx,
    known_parameters="None – all discrete parameters are unspecified.",
    parameters_to_resolve=(
        "arm  (choose LEFT or RIGHT based on object position)\n"
        "approach_direction  (FRONT / BACK / LEFT / RIGHT)\n"
        "vertical_alignment  (TOP / BOTTOM / NoAlignment)\n"
        "rotate_gripper      (true / false)"
    ),
    prompt=pick_up_resolver_prompt,
    schema_cls=PickUpDiscreteResolutionSchema,
)

print("run_resolver() output (PickUpDiscreteResolutionSchema):")
print(f"  arm                : {resolution.arm}")
print(f"  approach_direction : {resolution.approach_direction}")
print(f"  vertical_alignment : {resolution.vertical_alignment}")
print(f"  rotate_gripper     : {resolution.rotate_gripper}")
print(f"  reasoning          : {resolution.reasoning}")
